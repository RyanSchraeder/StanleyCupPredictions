# %%
import numpy as np
import pandas as pd 
from typing import Any, Dict
import seaborn as sns
import matplotlib.pyplot as plt

# Models
import xgboost as xgb 
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier

## Pre-Processing
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

## Scoring 
import scipy.stats as stats
from sklearn import metrics
from sklearn.metrics import confusion_matrix

## Data Source: https://www.hockey-reference.com/leagues/NHL_2022.html ##

# %% [markdown]
# # NHL 2022 Season Performance Predictions
#
# In this analysis, I use current known stats in the NHL to predict outcomes for a team matchup. With statistical testing, exploratory analysis, and some classification algorithms, my goal is to determine the likelihood of an accurate prediction.

# %% [markdown]
# ## Datasets
#
# The data included is very robust, including all current information and some metrics for team performance. I import a league history of games during the regular season as well as each team's overall stats. You'll notice I incorporated feature engineering into the imports. This helps me keep things tight so I don't worry about conflicts after merging the data together.

# %%
df = pd.read_csv('../data/team_stats.csv')

# Creating Column for Total Goals 
df['G'] = df.GF + df.GA 
# Creating Column for Total Power-Play Goals 
df['PPG'] = df.PP + df. PPA
# Creating Column for Total Games in Shootouts
df['SHOOTOUTS'] = df.SOW + df. SOL

df.head()
# df.isna().sum() -- just a check for missing data.
# Out:
#    Rk                 Team  AvAge  GP   W   L  OL  PTS   PTS%   GF  ...  \
# 0   1     Florida Panthers   27.8  82  58  18   6  122  0.744  337  ...
# 1   2   Colorado Avalanche   28.2  82  56  19   7  119  0.726  308  ...
# 2   3  Carolina Hurricanes   28.3  82  54  20   8  116  0.707  277  ...
# 3   4  Toronto Maple Leafs   28.4  82  54  21   7  115  0.701  312  ...
# 4   5       Minnesota Wild   29.4  82  53  22   7  113  0.689  305  ...
#
#    PIM/G  oPIM/G     S    S%    SA    SV%  SO    G  PPG  SHOOTOUTS
# 0   10.1    10.8  3062  11.0  2515  0.904   5  579  117          7
# 1    9.0    10.4  2874  10.7  2625  0.912   7  540  115          6
# 2    9.2     7.7  2798   9.9  2310  0.913   6  477   84          3
# 3    8.6     8.5  2835  11.0  2511  0.900   7  564  105          4
# 4   10.8    10.8  2666  11.4  2577  0.903   3  554  116          9
#
# [5 rows x 35 columns]

# %%
games = pd.read_csv('../data/regular_season_games.csv').drop(columns=({'Unnamed: 5', 'Notes', 'Att.'})).rename(columns=({
    "Date": "date",
    "Visitor": "away_team",
    "Home": "home_team",
    "G": "away_goals", 
    "G.1": "home_goals",
    "LOG": "length_of_game_min"
}))
games['outcome'] = (games.away_goals - games.home_goals).apply(lambda x: 'away' if x > 0 else 'home')
games['outcome'] = games['outcome'].apply(lambda x: 1 if x == 'away' else 0)

home_win_mask = games['outcome'] == 0 
games['home_wins'] = np.where(home_win_mask, 1, 0)

games['date'] = games['date'].astype('datetime64')
games.head()
# games.isna().sum() -- just a check for missing data.
# Out:
#         date            away_team  away_goals             home_team  \
# 0 2021-10-12  Pittsburgh Penguins           6   Tampa Bay Lightning
# 1 2021-10-12       Seattle Kraken           3  Vegas Golden Knights
# 2 2021-10-13        Winnipeg Jets           1         Anaheim Ducks
# 3 2021-10-13   Chicago Blackhawks           2    Colorado Avalanche
# 4 2021-10-13    Vancouver Canucks           2       Edmonton Oilers
#
#    home_goals length_of_game_min  outcome  home_wins
# 0           2               2:33        1          0
# 1           4               2:25        0          1
# 2           4               2:29        0          1
# 3           4               2:32        0          1
# 4           3               2:42        0          1

# %%
playoffs = pd.read_csv('../data/playoffs.csv')
playoffs = playoffs.head()
playoffs
# Out:
#     Rk                 Team    GP    W    L    T   OW   OL   W-L%     G    GA  \
# 0  1.0   Colorado Avalanche  10.0  8.0  2.0  0.0  2.0  1.0  0.800  43.0  27.0
# 1  2.0  Tampa Bay Lightning  11.0  8.0  3.0  0.0  1.0  0.0  0.727  36.0  27.0
# 2  3.0      Edmonton Oilers  12.0  8.0  4.0  0.0  1.0  1.0  0.667  52.0  37.0
# 3  4.0  Carolina Hurricanes  13.0  7.0  6.0  0.0  1.0  0.0  0.538  35.0  34.0
# 4  5.0     New York Rangers  13.0  7.0  6.0  0.0  1.0  2.0  0.538  42.0  40.0
#
#    DIFF
# 0    16
# 1     9
# 2    15
# 3     1
# 4     2

# %% [markdown]
# ### Glossary
#
# - Rk -- Rank
# - AvAge -- Average age of team weighted by time on ice.
# - GP -- Games Played
# - W -- Wins
# - L -- Losses
# - OL -- Overtime/Shootout Losses (2000 season onward)
#
# **_Scoring_**
# - PTS -- Points
# - PTS% -- Points percentage (i.e., points divided by maximum points)
# - GF -- Goals For
#
# **_Goalie Stats_**
# - GA -- Goals Against
# - SOW -- Shootout Wins
# - SOL -- Shootout Losses
# - SRS -- Simple Rating System; a team rating that takes into account average goal differential and strength of schedule. The rating is denominated in goals above/below average, where zero is average.
# - SOS -- Strength of Schedule; a rating of strength of schedule. The rating is denominated in goals above/below average, where zero is average.
# - GF/G -- Goals For Per Game
# - GA/G -- Goals Against Per Game
#
# **_Special Teams_**
# - PP -- Power Play Goals
# - PPO -- Power Play Opportunities
# - PP% -- Power Play Percentage
# - PPA -- Power Play Goals Against
# - PPOA -- Power Play Opportunities Against
# - PK% -- Penalty Killing Percentage
# - SH -- Short-Handed Goals
# - SHA -- Short-Handed Goals Against
# - PIM/G -- Penalties in Minutes Per Game
# - oPIM/G -- Opponent Penalties in Minutes Per Game
#
# **_Shot Data_**
# - S -- Shots on Goal
# - S% -- Shooting Percentage
# - SA -- Shots Against
# - SV% -- Save Percentage
#
# **_Goalie Stats_**
# - SO -- Shutouts
#
# **_Regular Season History_**
# - Date of Game
# - Away & Home Teams
# - Away & Home Goals
# - Duration of Game
#
# **_Playoff Game History to Date_**
# - Rk -- Rank
# - GP -- Games Played
# - W -- Wins
# - L -- Losses
# - T -- Ties
# - OW -- Overtime/Shootout Wins
# - OL -- Overtime/Shootout Losses (2000 season onward)
# - W-L% -- Win-Loss Percentage (i.e., wins plus one-half ties, divided by games played)
# - G -- Goals
# - DIFF -- Goal Differential (i.e., Goals minus Goals Against)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# At first glance, some potential metrics indicating win-potential could be:
# - Goal Differential (goals for versus against a team)
# - Points Percentage (PTS%)
# - Win/Loss ratio
# - Overtime Losses (OL)
# - Shootout W/L Ratio
# - Penalty Killing Percentage (PK%)
# - Power Play Performance Ratio: Power Play Goals (PP) versus Power Play Goals Against (PPA)
# - Save Percentage (SV%), or save efficiency
# - Shooting Percentage (S%), or accuracy
#
# Few of these exist within the data and some will need to be extracted as features.

# %% [markdown]
# ### Correlations
#
# Plotting correlations in the data, I'm looking at any relationships at least 70% positively correlated and less than a 100% correlation (absolute) to focus on variables of interest.

# %%
## Correlation Matrix
import seaborn as sns
import matplotlib.pyplot as plt 

plt.figure(figsize=(12,8))

# corr = df.corr() - all correlations
corr = df[['W', 'L', 'PTS', 'PTS%', 'SRS', 'SOS', 'PP', 'PP%']].corr()
corr = corr[np.logical_and(corr>0.70, corr<.9999)].abs()

## Determining strongest correlation patterns
strong_corrs_df = pd.DataFrame({k:v for k, v in corr[~corr.isna()].max().dropna().items()}, index=[0])

sns.heatmap(corr, annot=True)

plt.show()

strong_corrs_df
# Out:
#           W         L       PTS      PTS%       SRS       SOS        PP  \
# 0  0.993766  0.912203  0.993766  0.993735  0.973541  0.912203  0.944115
#
#         PP%
# 0  0.944115

# %% [markdown]
# ### Summary
#
# Looking at the strongest of correlations, we can tell that Wins, Losses, Points, Point Percentage, the Simple Rating System (SRS), Strength of Schedule, Power Play, and Power Play Percentage are the most correlated variables. Here are the strongest correlations:
#
# - **Wins to Points & Point Percentage**
# - **Points & Point Percentage to SRS**
# - **Wins to SRS**
# - **Losses to Strength of Schedule (SOS)**
# - **Power Play to Power Play Percentage**
#
# The SRS is an all-around stat measuring a team's goal differential to the strength of their game schedule. If they had performed at home to a weaker team, they would have a high schedule strength. Paired with the positive goal differential, this means the team is fairly dominant.

# %% [markdown]
# ## Feature Engineering
# > Determining features based upon EDA, and working towards diving further into them
#
# It appears that I'll need to focus on win, point, power play, and schedule statistics. Given I didn't see any correlation from goals for or against and wins, I'll need to create some features that summarize goals and can draw statistics from them we can measure based upon wins. These can be tied in as performance metrics, and if conducive, will reveal more insight into the top teams in the league.

# %%
## Creating percentages for new metrics and columns
def ratio_maker(df: pd.DataFrame, newcol: str, xcol: str, ycol: str) -> Any: 
    df[f"{newcol}"] = (df[f"{xcol}"] / df[f"{ycol}"])*100

## Calc new metrics and store in new cols 
ratio_maker(df, "W%", "W", "GP") # win-loss percentage
ratio_maker(df, "GDIFF", "GF", "G") # goal differential
ratio_maker(df, "SOW%", "SOW", "SHOOTOUTS") # shootout win-loss ratio 
ratio_maker(df, "PPW%", "PP", "PPG") # power-play success percentage

df.head()
# Out:
#    Rk                 Team  AvAge  GP   W   L  OL  PTS   PTS%   GF  ...    SA  \
# 0   1     Florida Panthers   27.8  82  58  18   6  122  0.744  337  ...  2515
# 1   2   Colorado Avalanche   28.2  82  56  19   7  119  0.726  308  ...  2625
# 2   3  Carolina Hurricanes   28.3  82  54  20   8  116  0.707  277  ...  2310
# 3   4  Toronto Maple Leafs   28.4  82  54  21   7  115  0.701  312  ...  2511
# 4   5       Minnesota Wild   29.4  82  53  22   7  113  0.689  305  ...  2577
#
#      SV%  SO    G  PPG  SHOOTOUTS         W%      GDIFF       SOW%       PPW%
# 0  0.904   5  579  117          7  70.731707  58.203800  42.857143  54.700855
# 1  0.912   7  540  115          6  68.292683  57.037037  66.666667  58.260870
# 2  0.913   6  477   84          3  65.853659  58.071279  33.333333  60.714286
# 3  0.900   7  564  105          4  65.853659  55.319149  75.000000  60.000000
# 4  0.903   3  554  116          9  64.634146  55.054152  55.555556  45.689655
#
# [5 rows x 39 columns]

# %% [markdown]
# _Here, I created:_
# - a win percentage (W%)
# - goal differential (GDIFF)
# - win percentage in games leading to shootout (SOW%)
# - performance on the power play (PPW%)

# %%
# As an example, here are the top ten teams with these metrics. 

winners = df[['Rk','Team','W%', 'GDIFF', 'SOW%', 'PPW%']].sort_values('Rk', ascending=True).head(10)
winners
# Out:
#    Rk                 Team         W%      GDIFF       SOW%       PPW%
# 0   1     Florida Panthers  70.731707  58.203800  42.857143  54.700855
# 1   2   Colorado Avalanche  68.292683  57.037037  66.666667  58.260870
# 2   3  Carolina Hurricanes  65.853659  58.071279  33.333333  60.714286
# 3   4  Toronto Maple Leafs  65.853659  55.319149  75.000000  60.000000
# 4   5       Minnesota Wild  64.634146  55.054152  55.555556  45.689655
# 5   6       Calgary Flames  60.975610  58.551308  50.000000  56.250000
# 6   7  Tampa Bay Lightning  62.195122  55.555556  28.571429  55.855856
# 7   8     New York Rangers  63.414634  55.066079  57.142857  57.894737
# 8   9      St. Louis Blues  59.756098  56.386861  40.000000  65.000000
# 9  10        Boston Bruins  62.195122  53.715499  50.000000  50.505051

# %% [markdown]
# As we can see, the Florida Panthers are on top and the remaining ranking teams are pretty close to the actual standings. Some key takeways:
# - Shootouts (SOW%) are low for teams currently in the playoffs and performing well: Tampa Bay Lightning (28.5%), Carolina Hurricanes (33.33%), Florida Panthers (42.8%).
# - The upper bound of all metrics shows a high win-loss percentage, meaning a positive record
#
# #### Averaging the Metrics
# By taking the averages of goal differential, shootout win percentage, and power-play win percentage, I want to see if the overall win percentage is affected

# %%
avg = []
for i, j in winners.iloc[:,2:].iterrows(): 
    avg.append(j.mean())
    
winners['avg_overall'] = avg
winners = winners.sort_values('avg_overall', ascending=False)
winners
# Out:
#    Rk                 Team         W%      GDIFF       SOW%       PPW%  \
# 3   4  Toronto Maple Leafs  65.853659  55.319149  75.000000  60.000000
# 1   2   Colorado Avalanche  68.292683  57.037037  66.666667  58.260870
# 7   8     New York Rangers  63.414634  55.066079  57.142857  57.894737
# 0   1     Florida Panthers  70.731707  58.203800  42.857143  54.700855
# 5   6       Calgary Flames  60.975610  58.551308  50.000000  56.250000
# 8   9      St. Louis Blues  59.756098  56.386861  40.000000  65.000000
# 4   5       Minnesota Wild  64.634146  55.054152  55.555556  45.689655
# 2   3  Carolina Hurricanes  65.853659  58.071279  33.333333  60.714286
# 9  10        Boston Bruins  62.195122  53.715499  50.000000  50.505051
# 6   7  Tampa Bay Lightning  62.195122  55.555556  28.571429  55.855856
#
#    avg_overall
# 3    64.043202
# 1    62.564314
# 7    58.379577
# 0    56.623376
# 5    56.444229
# 8    55.285740
# 4    55.233377
# 2    54.493139
# 9    54.103918
# 6    50.544490

# %% [markdown]
# An interesting note here is the high shootout performance of the Toronto Maple Leafs. Their overall win percentage is close to their average overall success rate due to this. When looking at the Florida Panthers who are ranked first, however, they have the second highest goal differential but the highest win percentage. The statistic bringing their overall success down is their lesser performance than others in shootouts. It seems here that's the most important factor toward playoff readiness, which is understandable. The end game is winning.

# %%
plt.figure(figsize=(12,8))

winners_melt = pd.melt(winners, id_vars=['Rk', 'Team'], value_vars=['W%', 'GDIFF', 'SOW%', 'PPW%', 'avg_overall'])
winners_melt.sort_values('Rk')

ax = sns.boxplot(x='variable', y='value', data=winners_melt, color='lightskyblue')
ax = sns.swarmplot(x='variable', y='value', data=winners_melt, color='red')

# %% [markdown]
# The team performance is indicated by rank, and the rank appears to be directly related to the higher level of these statistics:
#
# - Goal differential is not as varied, showing it is hard to get a high differential.
# - The widest range here is shootout win percentages - teams with the best seem to be rated the best.
#
# > Statistical Tests
# >- i) To ensure this is accurate, I can conduct a One-Way ANoVA (multiple factor test to determine the variance of variables results in a group mean of zero, if true, and therefore significant in influencing an output).
# >- ii) I also noticed that rank as an output variable would be a reliable predictor. To test this, I can add a Spearman's Rho correlation test as rank data is scaled. This will show what correlates with rank significantly.

# %% [markdown]
# ### Hypothesis Testing
#
# Given enough analysis, I'll form some hypotheses to test formally:
#
# - _H0_: Goal differential, shootout wins, penalty kill and power-play wins all have equal means, and thus have a direct impact on overall team record
# - _H1_: All such variables do not have equal means, and thus no impact on overall team record
#
# Ranked Hypotheses:
#
# - _H0_: Features seen positively correlated with game wins have a strong positive correlation with the team's league rank.
# - _H1_: All such variables do not have an impact on the team's league rank.

# %%
## One-Way ANOVA

fvalue, pvalue = stats.f_oneway(df['W%'], df['GDIFF'], df['SOW%'], df['PP%'], df['PK%'])
fvalue, pvalue
# Out:
# (134.06863479147813, 2.9106533090955316e-49)

# %%
## Spearman's RHO Ranked Test. 

spearman = df[['Rk', 'GDIFF', 'SOW%', 'PTS', 'PTS%', 'SRS', 'SOS', 'PP', 'PP%', 'PK%']].corr(method='spearman')
spearman[:1].abs()
# Out:
#      Rk     GDIFF      SOW%       PTS      PTS%       SRS       SOS        PP  \
# Rk  1.0  0.962977  0.043815  0.999908  0.999908  0.970119  0.924839  0.820692
#
#          PP%       PK%
# Rk  0.747801  0.522823

# %% [markdown]
# #### Summary
#
# 1) One-Way ANOVA
#
# The test concludes with a high f-statistic, which is expected. The percentages are widely varied and there are 32 teams. The p-value suggests that among the variance, group means are equal for the metrics selected and thus influence win rate. The alternate hypothesis is proven, so these tested variables have a significant impact on overall wins.
#
# 2) Spearman's RHO Rank Test
#
# The test concludes with a high correlation spread. I took the absolute value, since as the rank goes up, there is a negative implication. The lower the rank, the better the team. As seen in the summary of correlations, the points and goal differential determine a team's rank, but that is determined heavily upon the strength of their schedule and their powerplay performance. If a team is reliable on the power-play, they tend to perform better. This makes sense given a team will need to draw penalties from their opponent to gain an additional player or even 5-on-3 advantage, which increases odds for players to get goals.

# %% [markdown]
# # Classification of Numerical Variables
#
# > Encoding categorical values
# > Some features are still categorical and will be converted if deemed necessary, then I'll join the dataframes together to complete the dataset for my train and testing split

# %%
# Create full dataframe 
classification_df = games.merge(df, how='outer', left_on='away_team', right_on='Team')

# Encode non-numeric variables
classification_df.home_team = classification_df.home_team.astype('category').cat.codes 
classification_df.away_team = classification_df.away_team.astype('category').cat.codes

## convert length of game to minutes
new_vals = []
for i, j in enumerate(classification_df.length_of_game_min.str.split(':')):
    j = (int(j[0])*60) + int(j[1])
    new_vals.append(j)

classification_df.length_of_game_min = new_vals

## add datetime features
classification_df["day_code"] = classification_df["date"].dt.dayofweek

## Remove date, team variables as team is redundant and date cannot be trained. 
classification_df = classification_df.iloc[:, (classification_df.columns != 'date') & (classification_df.columns != 'Team')]
classification_df.head()
# Out:
#    away_team  away_goals  home_team  home_goals  length_of_game_min  outcome  \
# 0         22           6         26           2                 153        1
# 1         22           4         12           5                 160        0
# 2         22           2          6           3                 161        0
# 3         22           3         20           6                 142        0
# 4         22           1         30           6                 141        0
#
#    home_wins  Rk  AvAge  GP  ...    SV%  SO    G  PPG  SHOOTOUTS         W%  \
# 0          0  12   29.7  82  ...  0.914   7  491   83         10  56.097561
# 1          1  12   29.7  82  ...  0.914   7  491   83         10  56.097561
# 2          1  12   29.7  82  ...  0.914   7  491   83         10  56.097561
# 3          1  12   29.7  82  ...  0.914   7  491   83         10  56.097561
# 4          1  12   29.7  82  ...  0.914   7  491   83         10  56.097561
#
#        GDIFF  SOW%       PPW%  day_code
# ...

# %%
# Game Outcome Predictors 
x = classification_df.loc[:, classification_df.columns != 'outcome']
y = classification_df['outcome']

# Use a train and test split for initial training & testing, then apply predictions
# to the initial data

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.30, random_state=42)

# Length of Values
for i in (x_train, x_test, y_train, y_test): 
    print(len(i))
# Out:
# 918
# 394
# 918
# 394

# %%
# Algos 
logit = LogisticRegression(random_state=42)
svm = SVC(kernel='rbf', gamma=0.05)
random_forest = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

## Fits & Predictions
svm.fit(x_train, y_train)
svm_predictions = svm.predict(x_test) 

logit = logit.fit(x_train, y_train)
logit_predictions = logit.predict(x_test)

random_forest = random_forest.fit(x_train, y_train)
random_forest_predictions = random_forest.predict(x_test)
# Out:
# /Users/rschraeder/Library/Caches/pypoetry/virtualenvs/stanley-cup-predictions-z06k619M-py3.9/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Model Accuracy: how often is the classifier correct?
accsvm = metrics.accuracy_score(y_test, svm_predictions)
acclogit = metrics.accuracy_score(y_test, logit_predictions)
accrf = metrics.accuracy_score(y_test, random_forest_predictions)

# Model Precision: what percent of true positives does the classifier have when compared to false positives?
# i.e. - How many predictions are accurate?
# tp / (tp + fp)

precsvm = metrics.precision_score(y_test, svm_predictions)
preclogit = metrics.precision_score(y_test, logit_predictions)
precrf = metrics.precision_score(y_test, random_forest_predictions)

# Model Recall: what percent of true positives does the classifier have when compared to false negatives?
# i.e. How many predictions ar
# tp / (tp + fn)
recsvm = metrics.recall_score(y_test, svm_predictions)
reclogit = metrics.recall_score(y_test, logit_predictions)
recrf = metrics.recall_score(y_test, random_forest_predictions)

scores_table = pd.DataFrame({
    'Model': ['svm', 'logit', 'rf'],
    'Accuracy': [accsvm, acclogit, accrf],
    'Precision': [precsvm, preclogit, precrf],
    'Recall': [recsvm, reclogit, recrf]
})
scores_table
# Out:
#    Model  Accuracy  Precision    Recall
# 0    svm  0.730964   0.726667  0.626437
# 1  logit  0.837563   0.819767  0.810345
# 2     rf  1.000000   1.000000  1.000000

# %% [markdown]
# # Assessing Output Predictions
#
# Per the classification of the categorical game outcome, predictions are:
# - _*Home Win*_ : 0
# - _*Away Win*_ : 1
#
# In each crosstab table, the predictions are matched with the actual data. The confusion matrix will show the:
# - True Positives
# - False Positives
# - True Negatives
# - False Negatives

# %% [markdown]
# ### SVM Away Outcome

# %%
plt.figure(figsize=(12,8))

# Confusion Matrix Plot
conf_matrix_svm = confusion_matrix(y_test, svm_predictions)
ax = sns.heatmap(conf_matrix_svm/np.sum(conf_matrix_svm), annot=True, cmap='Reds', fmt='.2%')
ax.set_title('Confusion Matrix for SVM Predicted Outputs')
ax.set_xlabel('Predictions')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['Home', 'Away'])
ax.yaxis.set_ticklabels(['Home', 'Away'])

# SVM Confusion Matrix
combined = pd.DataFrame(dict(actual=y_test, predicted=svm_predictions))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          179   41
# 1           65  109

# %% [markdown]
# ### Logistic Regression Away Outcome

# %%
plt.figure(figsize=(12,8))

# Confusion Matrix Plot
conf_matrix_logit = confusion_matrix(y_test, logit_predictions)
ax = sns.heatmap(conf_matrix_logit/np.sum(conf_matrix_logit), annot=True, cmap='Reds', fmt='.2%')
ax.set_title('Confusion Matrix for Logistic Regression Predicted Outputs')
ax.set_xlabel('Predictions')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['Home', 'Away'])
ax.yaxis.set_ticklabels(['Home', 'Away'])

# Logistic Regression Confusion Matrix
combined = pd.DataFrame(dict(actual=y_test, predicted=logit_predictions))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          189   31
# 1           33  141

# %% [markdown]
# ### Random Forest Away Outcome

# %%
# Confusion Matrix Plot
plt.figure(figsize=(12,8))

conf_matrix_rf = confusion_matrix(y_test, random_forest_predictions)
ax = sns.heatmap(conf_matrix_rf/np.sum(conf_matrix_rf), annot=True, cmap='Reds', fmt='.2%')
ax.set_title('Confusion Matrix for Random Forest Predicted Outputs')
ax.set_xlabel('Predictions')
ax.set_ylabel('Actual')
ax.xaxis.set_ticklabels(['Home', 'Away'])
ax.yaxis.set_ticklabels(['Home', 'Away'])

# Random Forest Confusion Matrix
combined = pd.DataFrame(dict(actual=y_test, predicted=random_forest_predictions))
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0    1
# actual
# 0          220    0
# 1            0  174

# %%
# Map Predictions Back to Data
svm.fit(x, y)
games['svm_away_wins'] = svm.predict(x) 
logit.fit(x, y)
games['logit_away_wins'] = logit.predict(x)
random_forest.fit(x, y)
games['rf_away_wins'] = random_forest.predict(x)
# Out:
# /Users/rschraeder/Library/Caches/pypoetry/virtualenvs/stanley-cup-predictions-z06k619M-py3.9/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(

# %%
# Model Accuracy: how often is the classifier correct?
final_accsvm = metrics.accuracy_score(y, svm.predict(x))
final_acclogit = metrics.accuracy_score(y, logit.predict(x))
final_accrf = metrics.accuracy_score(y, random_forest.predict(x))

# Model Precision: what percent of true positives does the classifier have when compared to false positives?
# i.e. - How many predictions are accurate?
# tp / (tp + fp)

final_precsvm = metrics.precision_score(y, svm.predict(x))
final_preclogit = metrics.precision_score(y, logit.predict(x))
final_precrf = metrics.precision_score(y, random_forest.predict(x))

# Model Recall: what percent of true positives does the classifier have when compared to false negatives?
# i.e. How many predictions ar
# tp / (tp + fn)
final_recsvm = metrics.recall_score(y, svm.predict(x))
final_reclogit = metrics.recall_score(y, logit.predict(x))
final_recrf = metrics.recall_score(y, random_forest.predict(x))

final_scores_table = pd.DataFrame({
    'Model': ['svm', 'logit', 'rf'],
    'Accuracy': [accsvm, acclogit, accrf],
    'Precision': [precsvm, preclogit, precrf],
    'Recall': [recsvm, reclogit, recrf]
})
final_scores_table
# Out:
#    Model  Accuracy  Precision    Recall
# 0    svm  0.730964   0.726667  0.626437
# 1  logit  0.837563   0.819767  0.810345
# 2     rf  1.000000   1.000000  1.000000

# %%
games = games.rename(columns=({'away_team': 'team', 'outcome': 'away_wins'}))
summary = games.groupby('team').sum()
summary
# Out:
#                        away_goals  home_goals  away_wins  home_wins  \
# team
# Anaheim Ducks                 117         147         14         27
# Arizona Coyotes               104         158         14         27
# Boston Bruins                 123         106         25         16
# Buffalo Sabres                109         149         15         26
# Calgary Flames                137         109         25         16
# Carolina Hurricanes           143         113         25         16
# Chicago Blackhawks            108         141         14         27
# Colorado Avalanche            140         127         24         17
# Columbus Blue Jackets         121         158         16         25
# Dallas Stars                  106         133         19         22
# Detroit Red Wings              99         157         14         27
# Edmonton Oilers               134         124         21         20
# Florida Panthers              148         127         24         17
# ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# In summary, the models trained especially well with test data and similar results yield from training them on the original data. The random forest algorithm is overfit with 100% accuracy and appears to have been confused with the binary inputs and classification variables, so some cross-validation and better processing will need to be done.
